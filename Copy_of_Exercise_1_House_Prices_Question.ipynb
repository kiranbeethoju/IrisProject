# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranbeethoju/IrisProject/blob/master/Copy_of_Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
xs = np.array([1.0,2.0,3.0,4.0],dtype=float)
ys = np.array([100.0,150.0,200.0,250.0],dtype=float)
model.fit(xs,ys,epochs=700)
print(model.predict([7.0]))
# Out:
# Epoch 1/700
# 4/4 [==============================] - 0s 14ms/sample - loss: 32547.6621
# Epoch 2/700
# 4/4 [==============================] - 0s 415us/sample - loss: 22629.0781
# Epoch 3/700
# 4/4 [==============================] - 0s 695us/sample - loss: 15746.5127
# Epoch 4/700
# 4/4 [==============================] - 0s 526us/sample - loss: 10970.5781
# Epoch 5/700
# 4/4 [==============================] - 0s 399us/sample - loss: 7656.3945
# Epoch 6/700
# 4/4 [==============================] - 0s 426us/sample - loss: 5356.4878
# Epoch 7/700
# 4/4 [==============================] - 0s 363us/sample - loss: 3760.3691
# Epoch 8/700
# 4/4 [==============================] - 0s 379us/sample - loss: 2652.5947
# Epoch 9/700
# 4/4 [==============================] - 0s 344us/sample - loss: 1883.6748
# Epoch 10/700
# 4/4 [==============================] - 0s 374us/sample - loss: 1349.8794
# Epoch 11/700
# 4/4 [==============================] - 0s 547us/sample - loss: 979.2340
# Epoch 12/700
# ...
